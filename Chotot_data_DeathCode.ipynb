# %%
import pandas as pd
#Read Electronic Folder
ads = pd.read_json("./electronic/ads", lines=True, encoding = "utf-8")
ad_params = pd.read_json("./electronic/ad_params", lines=True, encoding = "utf-8")

# %%
ads.sample(10)
# Out:
#            ad_id                     address  category  \
# 744339  89594136                         NaN     13010
# 851398  91153538                         NaN      2030
# 400876  91076134                         NaN      5060
# 634924  91123521                         NaN      9040
# 297864  90728734                         NaN      2020
# 364583  87942584             đuong nông thôn      1020
# 64592   89014974                         NaN      3060
# 598393  91196167       Đường Phan Đình Phùng      1010
# 201705  91285931  Đường Bắc Sơn - Long Thành      1040
# 556494  89273767                         NaN      5010
#
#                       category_name            city  city_id  company_ad  \
# 744339      Jobs looking for people          Hà Nội  12000.0        True
# 851398  Vehicles parts, Accessories  Tp Hồ Chí Minh  13000.0       False
# 400876                  Accessories  Tp Hồ Chí Minh  13000.0       False
# ...

# %%
ad_params.sample(10)
# Out:
#             ad_id            name  value
# 1783733  91291014    condition_ad      1
# 8683141  89293731         area_v2  13102
# 5169238  89481670    condition_ad      2
# 6080272  90423361        giveaway      0
# 7700595  87998747       region_v2   1008
# 5672141  80858711  motorbikemodel     25
# 7741662  91166791            area     97
# 514228   91379306           trade      0
# 6675396  90767227         area_v2  13117
# 4683259  88402227            ward   9146

# %%
ads.category_name.unique()
# Out:
# array(['Cat', 'Dog', 'Bags', 'Bird', 'Cars', 'Books', 'Shoes', 'Watch',
#        'Others', 'Travel', 'Trucks', 'Clothes', 'Desktop', 'Perfume',
#        'Rooster', 'Tablets', 'Bicycles', 'PTY-Land', 'Services',
#        'Other pet', 'PTY-Rooms', 'Components', 'Motorbikes', 'PTY-Houses',
#        'Accessories', 'Video games', 'Mom and kids', 'Mobile Phones',
#        'Other hobbies', 'Other Vehicles', 'PTY-Apartments',
#        'Smart wearables', 'Funiture, Plants', 'Sports, Outdoors',
#        'Electric vehicles', 'Office Equipments', 'Other accessories',
#        'Computers, Laptops', 'Musical instruments',
#        'Other household items', 'Cameras, Video Cameras',
#        'Collectibles, Antiques', 'Jobs looking for people',
#        'Other pets & equipments', 'People looking for jobs',
#        'TV, Speakers, MP3 players', 'Vehicles parts, Accessories',
#        'Fridge, Aircons, Washing machines',
#        'PTY-Office, Commercial Properties',
# ...

# %%
ads.category.unique()
# Out:
# array([12050, 12020,  3070, 12030,  2010,  4070,  3060,  3050,  7010,
#         6030,  2050,  3030,  5070,  3080, 12010,  5040,  2060,  1040,
#         6020, 12060,  1050,  5080,  2020,  1020,  5060,  4050, 11010,
#         5010,  4060,  2080,  1010,  5090,  9040,  4020,  2090,  8010,
#         3090,  5030,  4040,  9050,  5050,  4010, 13010, 12040, 13020,
#         5020,  2030,  9030,  1030,  8030])

# %%
adstas = pd.read_json("./electronic/adstats000000000000", lines=True, encoding = "utf-8")

# %%
adstas.sample(10)
# Out:
#          adlist_id adplacement  adposition    adsource  \
# 55607     63174547     default           1  classifyad
# 2269637   62939517     default          17  classifyad
# 693342    62341936         top           5    stickyad
# 2554749   61452797     default          20  classifyad
# 960647    59480751     default           7  classifyad
# 1160848   63128005     default           8  classifyad
# 349034    63099292     default           2  classifyad
# 1825573   62871378     default          14  classifyad
# 2559832   63216943     default          20  classifyad
# 1344761   62861614     default          10  classifyad
#
#                         event_name       event_server_time event_type  \
# 55607    adlisting/CLASSIFYAD_LOAD 2019-09-22 17:07:48.900       LOAD
# 2269637  adlisting/CLASSIFYAD_LOAD 2019-09-22 14:27:49.358       LOAD
# 693342     adlisting/STICKYAD_LOAD 2019-09-17 02:45:06.628       LOAD
# 2554749  adlisting/CLASSIFYAD_LOAD 2019-09-21 13:12:30.577       LOAD
# ...
